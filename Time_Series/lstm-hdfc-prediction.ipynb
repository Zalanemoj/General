# %% [markdown]
# # Basics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tqdm.auto as tqdm
import os

# %%
df=pd.read_csv('/kaggle/input/data-cleaning-historical/Cleaned_HDFCBANK.NS_MAX_NSE.csv')
df.head(5)
# Out:
#          date  close  open  high   low     volume
# 0  1995-06-14   2.27  2.30  2.30  2.25  2070000.0
# 1  1995-06-15   2.26  2.28  2.31  2.25  4246000.0
# 2  1995-06-18   2.26  2.26  2.27  2.22  1798000.0
# 3  1995-06-19   2.25  2.26  2.26  2.24  2792000.0
# 4  1995-06-20   2.27  2.33  2.33  2.27  1182000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7885 entries, 0 to 7884
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    7885 non-null   object
#  1   close   7885 non-null   float64
#  2   open    7885 non-null   float64
#  3   high    7885 non-null   float64
#  4   low     7885 non-null   float64
#  5   volume  7885 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 369.7+ KB

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.set_index('date',inplace=True)
df.head(5)
# Out:
#             close  open  high   low     volume
# date
# 1995-06-14   2.27  2.30  2.30  2.25  2070000.0
# 1995-06-15   2.26  2.28  2.31  2.25  4246000.0
# 1995-06-18   2.26  2.26  2.27  2.22  1798000.0
# 1995-06-19   2.25  2.26  2.26  2.24  2792000.0
# 1995-06-20   2.27  2.33  2.33  2.27  1182000.0

# %%
plt.figure(figsize=(15,4))
plt.plot(df.index,df['close'])
plt.savefig('Closing Price vs Years.png')
plt.show()

# %%
plt.figure(figsize=(15,4))
plt.plot(df.index,df['close'])
plt.xlim(pd.Timestamp('2020-01-01'),pd.Timestamp('2026-01-01'))
plt.ylim(350,1050)
plt.savefig('Closing Price vs Years with limit.png')
plt.show()

# %%
plt.figure(figsize=(15,4))
plt.bar(df.index, df['volume'], color='skyblue', width=0.8)
plt.xlim(pd.Timestamp('2020-01-01'),pd.Timestamp('2026-01-01'))
plt.savefig('Bar chart Volume.png')
plt.show()

# %% [markdown]
# # Featuer Adding

# %%
delta = df['close'].diff()
gain = delta.clip(lower=0)
loss = -delta.clip(upper=0)
avg_gain = gain.ewm(com=13, adjust=False, min_periods=14).mean()
avg_loss = loss.ewm(com=13, adjust=False, min_periods=14).mean()
rs = avg_gain / avg_loss
df['RSI'] = 100 - (100 / (1 + rs))
df.iloc[1:14, :]
# Out:
#             close  open  high   low     volume  RSI
# date
# 1995-06-15   2.26  2.28  2.31  2.25  4246000.0  NaN
# 1995-06-18   2.26  2.26  2.27  2.22  1798000.0  NaN
# 1995-06-19   2.25  2.26  2.26  2.24  2792000.0  NaN
# 1995-06-20   2.27  2.33  2.33  2.27  1182000.0  NaN
# 1995-06-21   2.23  2.27  2.27  2.22  1758000.0  NaN
# 1995-06-22   2.21  2.25  2.25  2.19   992000.0  NaN
# 1995-06-25   2.10  2.17  2.17  2.09  1656000.0  NaN
# 1995-06-26   2.08  2.10  2.10  2.02  1744000.0  NaN
# 1995-06-27   2.13  2.10  2.15  2.07  2038000.0  NaN
# 1995-06-28   2.11  2.13  2.15  2.10  1248000.0  NaN
# 1995-06-29   2.07  2.10  2.10  2.06  1224000.0  NaN
# 1995-07-02   1.99  2.00  2.08  1.97  1916000.0  NaN
# 1995-07-03   1.97  1.95  2.00  1.94  2310000.0  NaN

# %%
ema_12=df['close'].ewm(span=12,adjust=False).mean()
ema_26=df['close'].ewm(span=26,adjust=False).mean()
df['MACD']=ema_12-ema_26
df['signal']=df['MACD'].ewm(span=9,adjust=False).mean()
df['MACD_Hist']=df['MACD']-df['signal']
sma=df['close'].rolling(window=20).mean()
std=df['close'].rolling(window=20).std()
df['BB_Upper']=sma + (std*2)
df['BB_Lower']=sma - (std*2)
df['BB_Middle']=sma
high_low=df['high']-df['low']
high_close=abs(df['high']-df['close'].shift())
low_close=abs(df['low']-df['close'].shift())
tr=pd.concat([high_low,high_close,low_close],axis=1).max(axis=1)
df['ATR']=tr.rolling(window=14).mean()
df['ROC']=df['close'].pct_change(periods=12) * 100
df['volume_SMA']=df['volume'].rolling(window=20).mean()
df['volume_Ratio']=df['volume']/(df['volume_SMA'] + 1e-10)

# %%
df.dropna(inplace=True)

# %%
df.head(20)
# Out:
#             close  open  high   low     volume        RSI      MACD    signal  \
# date
# 1995-07-11   2.06  2.09  2.09  2.05   718000.0  35.169211 -0.062864 -0.060939
# 1995-07-12   2.08  2.07  2.09  2.05   886000.0  39.104961 -0.056110 -0.059973
# 1995-07-13   2.17  2.10  2.19  2.09  3996000.0  52.947754 -0.043000 -0.056579
# 1995-07-16   2.24  2.25  2.26  2.21  2028000.0  60.473804 -0.026654 -0.050594
# 1995-07-17   2.21  2.23  2.25  2.19  2252000.0  56.316335 -0.015937 -0.043662
# 1995-07-18   2.21  2.19  2.22  2.19  1176000.0  56.316335 -0.007358 -0.036401
# 1995-07-19   2.23  2.25  2.26  2.22  1352000.0  58.521123  0.001042 -0.028913
# 1995-07-20   2.20  2.20  2.23  2.18  1326000.0  54.109511  0.005218 -0.022087
# 1995-07-23   2.20  2.24  2.24  2.19  1144000.0  54.109511  0.008431 -0.015983
# 1995-07-24   2.19  2.21  2.21  2.17  1790000.0  52.577257  0.010054 -0.010776
# 1995-07-25   2.22  2.24  2.24  2.22   806000.0  56.552199  0.013604 -0.005900
# 1995-07-26   2.19  2.21  2.22  2.17   886000.0  51.870048  0.013837 -0.001952
# 1995-07-27   2.12  2.15  2.15  2.07   698000.0  42.937179  0.008279  0.000094
# 1995-07-30   2.08  2.07  2.10  2.05   704000.0  38.822770  0.000638  0.000203
# 1995-07-31   2.06  2.06  2.11  2.05   684000.0  36.917899 -0.006951 -0.001228
# 1995-08-01   2.11  2.11  2.11  2.09   366000.0  44.278699 -0.008829 -0.002748
# 1995-08-02   2.09  2.11  2.12  2.08   568000.0  42.159559 -0.011795 -0.004557
# 1995-08-03   2.09  2.00  2.10  2.00   430000.0  42.159559 -0.013984 -0.006443
# 1995-08-06   2.08  2.10  2.10  2.06   420000.0  41.021116 -0.016338 -0.008422
# 1995-08-07   2.07  2.08  2.10  2.06   722000.0  39.861916 -0.018794 -0.010496
#
#             MACD_Hist  BB_Upper  BB_Lower  BB_Middle       ATR        ROC  \
# date
# 1995-07-11  -0.001925  2.338681  1.888319     2.1135  0.070000  -1.904762
# 1995-07-12   0.003863  2.317088  1.890912     2.1040  0.068571   0.000000
# 1995-07-13   0.013579  2.302268  1.896732     2.0995  0.067857   1.877934
# 1995-07-16   0.023940  2.298108  1.898892     2.0985  0.068571   6.161137
# 1995-07-17   0.027726  2.290437  1.902563     2.0965  0.067143   6.763285
# 1995-07-18   0.029043  2.277751  1.909249     2.0935  0.065714  11.055276
# 1995-07-19   0.029955  2.277751  1.909249     2.0935  0.065714  13.197970
# 1995-07-20   0.027305  2.275970  1.910030     2.0930  0.061429  11.111111
# 1995-07-23   0.024414  2.287137  1.908863     2.0980  0.060714  11.675127
# 1995-07-24   0.020830  2.296785  1.910215     2.1035  0.058571   9.500000
# 1995-07-25   0.019504  2.307958  1.908042     2.1080  0.060000   9.359606
# 1995-07-26   0.015790  2.315299  1.908701     2.1120  0.060714   7.881773
# 1995-07-27   0.008185  2.316852  1.912148     2.1145  0.065714   2.912621
# 1995-07-30   0.000435  2.313547  1.924453     2.1190  0.062143   0.000000
# 1995-07-31  -0.005723  2.307408  1.939592     2.1235  0.062143  -5.069124
# 1995-08-01  -0.006080  2.301311  1.958689     2.1300  0.062857  -5.803571
# 1995-08-02  -0.007237  2.291381  1.980619     2.1360  0.057857  -5.429864
# 1995-08-03  -0.007541  2.284060  1.996940     2.1405  0.058571  -5.429864
# 1995-08-06  -0.007916  2.280052  2.005948     2.1430  0.057143  -6.726457
# 1995-08-07  -0.008297  2.276149  2.013851     2.1450  0.057857  -5.909091
#
#             volume_SMA  volume_Ratio
# date
# 1995-07-11   1816900.0      0.395179
# 1995-07-12   1757700.0      0.504068
# 1995-07-13   1745200.0      2.289709
# 1995-07-16   1756700.0      1.154437
# 1995-07-17   1729700.0      1.301960
# 1995-07-18   1729400.0      0.680005
# 1995-07-19   1709100.0      0.791060
# 1995-07-20   1725800.0      0.768339
# 1995-07-23   1700200.0      0.672862
# 1995-07-24   1702500.0      1.051395
# 1995-07-25   1640900.0      0.491194
# 1995-07-26   1622800.0      0.545970
# 1995-07-27   1596500.0      0.437206
# 1995-07-30   1535900.0      0.458363
# 1995-07-31   1454600.0      0.470232
# 1995-08-01   1367100.0      0.267720
# 1995-08-02   1311800.0      0.432993
# 1995-08-03   1291600.0      0.332920
# 1995-08-06   1220600.0      0.344093
# 1995-08-07   1147600.0      0.629139

# %% [markdown]
# # Train Test Split

# %%
features_cols=[]

for i in df.columns:
    features_cols.append(i)

print(features_cols)
# Out:
# ['close', 'open', 'high', 'low', 'volume', 'RSI', 'MACD', 'signal', 'MACD_Hist', 'BB_Upper', 'BB_Lower', 'BB_Middle', 'ATR', 'ROC', 'volume_SMA', 'volume_Ratio']

# %%
train_ratio,val_ratio=.8,.1
n=len(df)

train_end=int(n*train_ratio)
val_end=train_end + int(n * val_ratio)

train_data=df.iloc[:train_end]
val_data=df.iloc[train_end:val_end]
test_data=df.iloc[val_end:]

# %%
print(train_data.shape)
print(val_data.shape)
print(test_data.shape)
# Out:
# (6292, 16)
# (786, 16)
# (788, 16)

# %% [markdown]
# # Data Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
sclar=MinMaxScaler()
train_data=sclar.fit_transform(train_data[features_cols].values)
val_data=sclar.transform(val_data[features_cols].values)
test_data=sclar.transform(test_data[features_cols].values)

# %% [markdown]
# # Making Sequences

# %%
lookback=30
target=df.columns.get_loc('close')

def make_sequence(array,lookback,target):
    x,y=[],[]
    for i in range(len(array)-lookback-1):
        x.append(array[i:i+lookback])
        y.append(array[i+lookback,target])
    return np.array(x),np.array(y)

# %%
x_train,y_train=make_sequence(train_data,lookback,target)
x_val,y_val=make_sequence(val_data,lookback,target)
x_test,y_test=make_sequence(test_data,lookback,target)

# %%
x_train[1]
# Out:
# array([[1.34853308e-03, 1.32667395e-03, 1.35666168e-03, 1.33995428e-03,
#         2.20255556e-03, 3.46717545e-01, 4.66151193e-01, 4.86178671e-01,
#         3.57182767e-01, 1.25499396e-03, 1.46670919e-03, 1.23595065e-03,
#         2.09532045e-03, 2.72658388e-01, 2.82271366e-02, 3.25679827e-02],
#        [1.48965863e-03, 1.37349774e-03, 1.51259980e-03, 1.40301096e-03,
#         9.93387361e-03, 5.21080278e-01, 4.66573851e-01, 4.86314153e-01,
#         3.57955053e-01, 1.23228877e-03, 1.47623188e-03, 1.22875560e-03,
#         2.06206140e-03, 2.91889921e-01, 2.79682860e-02, 1.47938825e-01],
#        [1.59942295e-03, 1.60761667e-03, 1.62175649e-03, 1.59218097e-03,
#         5.04151544e-03, 6.15877800e-01, 4.67100810e-01, 4.86553008e-01,
#         3.58778615e-01, 1.22591506e-03, 1.47976645e-03, 1.22715670e-03,
#         2.09532045e-03, 3.35753311e-01, 2.82064286e-02, 7.45885628e-02],
#        [1.55238110e-03, 1.57640081e-03, 1.60616267e-03, 1.56065264e-03,
#         5.59836921e-03, 5.63510653e-01, 4.67446311e-01, 4.86829636e-01,
#         3.59079536e-01, 1.21416333e-03, 1.48577218e-03, 1.22395890e-03,
#         2.02880234e-03, 3.41919779e-01, 2.76473113e-02, 8.41200439e-02],
#        [1.55238110e-03, 1.51396910e-03, 1.55938124e-03, 1.56065264e-03,
#         2.92348232e-03, 5.63510653e-01, 4.67722858e-01, 4.87119409e-01,
#         3.59184260e-01, 1.19472730e-03, 1.49671216e-03, 1.21916219e-03,
#         1.96228423e-03, 3.85873167e-01, 2.76410989e-02, 4.39353163e-02],
#        [1.58374234e-03, 1.60761667e-03, 1.62175649e-03, 1.60794514e-03,
#         3.36101029e-03, 5.91281986e-01, 4.67993663e-01, 4.87418276e-01,
#         3.59256714e-01, 1.19472730e-03, 1.49671216e-03, 1.21916219e-03,
#         1.96228423e-03, 4.07816041e-01, 2.72207256e-02, 5.11106151e-02],
#        [1.53670048e-03, 1.52957703e-03, 1.57497505e-03, 1.54488847e-03,
#         3.29637548e-03, 5.35713673e-01, 4.68128298e-01, 4.87690704e-01,
#         3.59046080e-01, 1.19199818e-03, 1.49799058e-03, 1.21836274e-03,
#         1.76272990e-03, 3.86444959e-01, 2.75665500e-02, 4.96426492e-02],
#        [1.53670048e-03, 1.59200874e-03, 1.59056886e-03, 1.56065264e-03,
#         2.84393179e-03, 5.35713673e-01, 4.68231864e-01, 4.87934289e-01,
#         3.58816290e-01, 1.20910670e-03, 1.49608128e-03, 1.22635725e-03,
#         1.72947085e-03, 3.92220927e-01, 2.70364240e-02, 4.34738300e-02],
#        [1.52101987e-03, 1.54518495e-03, 1.54378743e-03, 1.52912430e-03,
#         4.44985830e-03, 5.16413527e-01, 4.68284192e-01, 4.88142112e-01,
#         3.58531389e-01, 1.22388830e-03, 1.49829333e-03, 1.23515120e-03,
#         1.62969368e-03, 3.69945906e-01, 2.70840525e-02, 6.79309675e-02],
#        [1.56806172e-03, 1.59200874e-03, 1.59056886e-03, 1.60794514e-03,
#         2.00367921e-03, 5.66481583e-01, 4.68398646e-01, 4.88336709e-01,
#         3.58426014e-01, 1.24100659e-03, 1.49473736e-03, 1.24234626e-03,
#         1.69621179e-03, 3.68508160e-01, 2.58084369e-02, 3.17361921e-02],
#        [1.52101987e-03, 1.54518495e-03, 1.55938124e-03, 1.52912430e-03,
#         2.20255556e-03, 5.07505572e-01, 4.68406170e-01, 4.88494249e-01,
#         3.58130791e-01, 1.25225389e-03, 1.49581529e-03, 1.24874186e-03,
#         1.72947085e-03, 3.53373985e-01, 2.54336213e-02, 3.52752916e-02],
#        [1.41125555e-03, 1.45153738e-03, 1.45022455e-03, 1.37148262e-03,
#         1.73519614e-03, 3.94987867e-01, 4.68226962e-01, 4.88575911e-01,
#         3.57526283e-01, 1.25463298e-03, 1.50145563e-03, 1.25273912e-03,
#         1.96228423e-03, 3.02485936e-01, 2.48889997e-02, 2.82480446e-02],
#        [1.34853308e-03, 1.32667395e-03, 1.37225549e-03, 1.33995428e-03,
#         1.75011187e-03, 3.43163098e-01, 4.67980648e-01, 4.88580255e-01,
#         3.56910308e-01, 1.24956908e-03, 1.52158990e-03, 1.25993417e-03,
#         1.79598896e-03, 2.72658388e-01, 2.36340922e-02, 2.96149913e-02],
#        [1.31717184e-03, 1.31106602e-03, 1.38784930e-03, 1.33995428e-03,
#         1.70039278e-03, 3.19169491e-01, 4.67735998e-01, 4.88523157e-01,
#         3.56420811e-01, 1.24016392e-03, 1.54636058e-03, 1.26712923e-03,
#         1.79598896e-03, 2.20746542e-01, 2.19505281e-02, 3.03818635e-02],
#        [1.39557493e-03, 1.38910567e-03, 1.38784930e-03, 1.40301096e-03,
#         9.09859295e-04, 4.11885547e-01, 4.67675459e-01, 4.88462490e-01,
#         3.56392375e-01, 1.23082264e-03, 1.57760796e-03, 1.27752209e-03,
#         1.82924801e-03, 2.13225223e-01, 2.01385741e-02, 1.72974742e-02],
#        [1.36421370e-03, 1.38910567e-03, 1.40344311e-03, 1.38724679e-03,
#         1.41202208e-03, 3.85193030e-01, 4.67579838e-01, 4.88390281e-01,
#         3.56300426e-01, 1.21560905e-03, 1.61349066e-03, 1.28711549e-03,
#         1.59643463e-03, 2.17052280e-01, 1.89934192e-02, 2.79758054e-02],
#        [1.36421370e-03, 1.21741845e-03, 1.37225549e-03, 1.26113344e-03,
#         1.06896037e-03, 3.85193030e-01, 4.67509254e-01, 4.88315039e-01,
#         3.56276254e-01, 1.20439320e-03, 1.64019512e-03, 1.29431055e-03,
#         1.62969368e-03, 2.17052280e-01, 1.85751167e-02, 2.15100940e-02],
#        [1.34853308e-03, 1.37349774e-03, 1.37225549e-03, 1.35571845e-03,
#         1.04410083e-03, 3.70853281e-01, 4.67433374e-01, 4.88236057e-01,
#         3.56246469e-01, 1.19825212e-03, 1.65493487e-03, 1.29830780e-03,
#         1.56317557e-03, 2.03774141e-01, 1.71048455e-02, 2.22319632e-02],
#        [1.33285246e-03, 1.34228188e-03, 1.37225549e-03, 1.35571845e-03,
#         1.79485905e-03, 3.56252090e-01, 4.67354210e-01, 4.88153271e-01,
#         3.56216161e-01, 1.19227260e-03, 1.66786585e-03, 1.30150561e-03,
#         1.59643463e-03, 2.12144620e-01, 1.55931581e-02, 4.06488766e-02],
#        [1.33285246e-03, 1.32667395e-03, 1.35666168e-03, 1.35571845e-03,
#         8.35280664e-04, 3.56252090e-01, 4.67299090e-01, 4.88073396e-01,
#         3.56239346e-01, 1.19105521e-03, 1.67080224e-03, 1.30230506e-03,
#         1.52991652e-03, 2.12144620e-01, 1.51976345e-02, 1.92371001e-02],
#        [1.33285246e-03, 1.32667395e-03, 1.34106786e-03, 1.33995428e-03,
#         8.75055934e-04, 3.56252090e-01, 4.67263438e-01, 4.88000668e-01,
#         3.56296292e-01, 1.19202651e-03, 1.66812867e-03, 1.30150561e-03,
#         1.46339841e-03, 2.16544462e-01, 1.46447297e-02, 2.06415253e-02],
#        [1.31717184e-03, 1.29545809e-03, 1.32547405e-03, 1.33995428e-03,
#         8.30308756e-04, 3.39135028e-01, 4.67217728e-01, 4.87931168e-01,
#         3.56322009e-01, 1.19085011e-03, 1.65138647e-03, 1.29271165e-03,
#         1.36362125e-03, 1.98850882e-01, 1.08530866e-02, 2.34895469e-02],
#        [1.31717184e-03, 1.32667395e-03, 1.34106786e-03, 1.35571845e-03,
#         7.50758216e-04, 3.39135028e-01, 4.67190374e-01, 4.87868796e-01,
#         3.56378792e-01, 1.17054264e-03, 1.64362234e-03, 1.27832154e-03,
#         1.29710314e-03, 2.11868302e-01, 9.06598225e-03, 2.34410338e-02],
#        [1.31717184e-03, 1.37349774e-03, 1.37225549e-03, 1.33995428e-03,
#         6.31432407e-04, 3.39135028e-01, 4.67177715e-01, 4.87815764e-01,
#         3.56453203e-01, 1.15599270e-03, 1.63461794e-03, 1.26632978e-03,
#         1.29710314e-03, 2.43675016e-01, 6.99724852e-03, 2.24041245e-02],
#        [1.33285246e-03, 1.31106602e-03, 1.35666168e-03, 1.35571845e-03,
#         9.09859295e-04, 3.70770202e-01, 4.67202430e-01, 4.87779458e-01,
#         3.56586452e-01, 1.13798447e-03, 1.63094318e-03, 1.25513747e-03,
#         1.23058503e-03, 2.67734930e-01, 6.15857269e-03, 3.41725101e-02],
#        [1.31717184e-03, 1.32667395e-03, 1.32547405e-03, 1.33995428e-03,
#         5.91657137e-04, 3.49005856e-01, 4.67204711e-01, 4.87750977e-01,
#         3.56648800e-01, 1.10973645e-03, 1.63329566e-03, 1.24154681e-03,
#         8.97994479e-04, 2.72658388e-01, 5.00513456e-03, 2.41666762e-02],
#        [1.28581061e-03, 1.29545809e-03, 1.32547405e-03, 1.29266178e-03,
#         1.77994332e-03, 3.07839093e-01, 4.67163671e-01, 4.87718032e-01,
#         3.56613230e-01, 1.08989752e-03, 1.62830360e-03, 1.22875560e-03,
#         8.31476369e-04, 2.38684198e-01, 4.37353918e-03, 7.63634680e-02],
#        [1.28581061e-03, 1.29545809e-03, 1.30988024e-03, 1.32419012e-03,
#         4.12668423e-04, 3.07839093e-01, 4.67140594e-01, 4.87685962e-01,
#         3.56620203e-01, 1.06570531e-03, 1.62796076e-03, 1.21596439e-03,
#         6.98440150e-04, 2.48158887e-01, 3.36091576e-03, 1.92589568e-02],
#        [1.28581061e-03, 1.24863431e-03, 1.29428643e-03, 1.26113344e-03,
#         8.35280664e-04, 3.07839093e-01, 4.67131852e-01, 4.87658142e-01,
#         3.56654059e-01, 1.04071079e-03, 1.63011103e-03, 1.20397263e-03,
#         6.98440150e-04, 2.48158887e-01, 1.85544086e-03, 4.48349183e-02],
#        [1.22308814e-03, 1.29545809e-03, 1.29428643e-03, 1.21384094e-03,
#         1.25292100e-03, 2.29781853e-01, 4.67031574e-01, 4.87611057e-01,
#         3.56500587e-01, 9.97437069e-04, 1.64032956e-03, 1.18638472e-03,
#         8.31476369e-04, 2.33270728e-01, 1.54274938e-03, 6.94171842e-02]])

# %% [markdown]
# # Model Making

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers,Sequential,regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint,ReduceLROnPlateau,TensorBoard
from tensorflow.keras.layers import LSTM, Dense
# Out:
# 2026-01-20 15:19:54.181606: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768922394.420184      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768922394.495002      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768922395.065818      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768922395.065861      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768922395.065864      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768922395.065867      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
strategy = tf.distribute.MirroredStrategy()
print(f'Number of devices: {strategy.num_replicas_in_sync}')
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2
# I0000 00:00:1768922408.725485      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1768922408.726172      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
with strategy.scope():
    model=Sequential(
        [
            layers.LSTM(64,activation='relu',return_sequences=True,input_shape=(lookback,len(features_cols))),
            layers.Dropout(.2),
    
            layers.LSTM(32,activation='relu',return_sequences=True),
            layers.Dropout(.2),
    
            layers.LSTM(16,activation='relu',return_sequences=False),
            layers.Dropout(.2),
    
            layers.Dense(1)
        ]
    )

    model.compile(
    optimizer="Adam",
    loss='mae',
    metrics=['mae']
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30, 64)         │        20,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 30, 32)         │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 16)             │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 36,305 (141.82 KB)
#  Trainable params: 36,305 (141.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping=tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=15,
    verbose=1,
    mode='auto',
    baseline=None,
    restore_best_weights=True,
    start_from_epoch=0
)

# %%
Checkpoints=tf.keras.callbacks.ModelCheckpoint(
    filepath='/kaggle/working/best_model.keras',
    monitor='val_loss',
    verbose=0,
    save_best_only=True,
    save_weights_only=False,
    mode='auto',
    save_freq='epoch'
)

# %%
lr=tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=3,
    verbose=0,
    mode='auto',
    min_delta=0.0001,
    cooldown=0
)

# %%
tensorboard=tf.keras.callbacks.TensorBoard(
    log_dir='/kaggle/working/logs',
    histogram_freq=0,
    write_graph=True,
    write_images=False,
    write_steps_per_second=False,
    update_freq='epoch',
    profile_batch=0,
    embeddings_freq=0,
    embeddings_metadata=None
)

# %% [markdown]
# # Training

# %%
history=model.fit(
    x_train,y_train,
    validation_data=(x_val,y_val),
    epochs=100,
    batch_size=128,
    callbacks=[early_stopping,Checkpoints,lr,tensorboard],
    verbose=1
)
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/100
# INFO:tensorflow:Collective all_reduce tensors: 11 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.1365 - mae: 0.1365INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 16s 158ms/step - loss: 0.1356 - mae: 0.1356 - val_loss: 0.0622 - val_mae: 0.0622 - learning_rate: 0.0010
# Epoch 2/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - loss: 0.0435 - mae: 0.0435 - val_loss: 0.0838 - val_mae: 0.0838 - learning_rate: 0.0010
# Epoch 3/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - loss: 0.0393 - mae: 0.0393 - val_loss: 0.0881 - val_mae: 0.0881 - learning_rate: 0.0010
# Epoch 4/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - loss: 0.0373 - mae: 0.0373 - val_loss: 0.0955 - val_mae: 0.0955 - learning_rate: 0.0010
# Epoch 5/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - loss: 0.0366 - mae: 0.0366 - val_loss: 0.0671 - val_mae: 0.0671 - learning_rate: 1.0000e-04
# Epoch 6/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - loss: 0.0349 - mae: 0.0349 - val_loss: 0.0591 - val_mae: 0.0591 - learning_rate: 1.0000e-04
# Epoch 7/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 142ms/step - loss: 0.0345 - mae: 0.0345 - val_loss: 0.0581 - val_mae: 0.0581 - learning_rate: 1.0000e-04
# Epoch 8/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - loss: 0.0317 - mae: 0.0317 - val_loss: 0.0677 - val_mae: 0.0677 - learning_rate: 1.0000e-04
# Epoch 9/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - loss: 0.0341 - mae: 0.0341 - val_loss: 0.0597 - val_mae: 0.0597 - learning_rate: 1.0000e-04
# Epoch 10/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - loss: 0.0346 - mae: 0.0346 - val_loss: 0.0611 - val_mae: 0.0611 - learning_rate: 1.0000e-04
# Epoch 11/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - loss: 0.0344 - mae: 0.0344 - val_loss: 0.0605 - val_mae: 0.0605 - learning_rate: 1.0000e-05
# Epoch 12/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - loss: 0.0334 - mae: 0.0334 - val_loss: 0.0570 - val_mae: 0.0570 - learning_rate: 1.0000e-05
# Epoch 13/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - loss: 0.0330 - mae: 0.0330 - val_loss: 0.0622 - val_mae: 0.0622 - learning_rate: 1.0000e-05
# Epoch 14/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - loss: 0.0345 - mae: 0.0345 - val_loss: 0.0610 - val_mae: 0.0610 - learning_rate: 1.0000e-05
# Epoch 15/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - loss: 0.0351 - mae: 0.0351 - val_loss: 0.0559 - val_mae: 0.0559 - learning_rate: 1.0000e-05
# Epoch 16/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - loss: 0.0331 - mae: 0.0331 - val_loss: 0.0550 - val_mae: 0.0550 - learning_rate: 1.0000e-05
# Epoch 17/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 146ms/step - loss: 0.0349 - mae: 0.0349 - val_loss: 0.0533 - val_mae: 0.0533 - learning_rate: 1.0000e-05
# Epoch 18/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - loss: 0.0363 - mae: 0.0363 - val_loss: 0.0537 - val_mae: 0.0537 - learning_rate: 1.0000e-05
# Epoch 19/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - loss: 0.0329 - mae: 0.0329 - val_loss: 0.0576 - val_mae: 0.0576 - learning_rate: 1.0000e-05
# Epoch 20/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - loss: 0.0343 - mae: 0.0343 - val_loss: 0.0546 - val_mae: 0.0546 - learning_rate: 1.0000e-05
# Epoch 21/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - loss: 0.0325 - mae: 0.0325 - val_loss: 0.0555 - val_mae: 0.0555 - learning_rate: 1.0000e-06
# Epoch 22/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - loss: 0.0356 - mae: 0.0356 - val_loss: 0.0558 - val_mae: 0.0558 - learning_rate: 1.0000e-06
# Epoch 23/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - loss: 0.0326 - mae: 0.0326 - val_loss: 0.0554 - val_mae: 0.0554 - learning_rate: 1.0000e-06
# Epoch 24/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - loss: 0.0335 - mae: 0.0335 - val_loss: 0.0554 - val_mae: 0.0554 - learning_rate: 1.0000e-07
# Epoch 25/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - loss: 0.0351 - mae: 0.0351 - val_loss: 0.0553 - val_mae: 0.0553 - learning_rate: 1.0000e-07
# Epoch 26/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - loss: 0.0348 - mae: 0.0348 - val_loss: 0.0553 - val_mae: 0.0553 - learning_rate: 1.0000e-07
# Epoch 27/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - loss: 0.0375 - mae: 0.0375 - val_loss: 0.0553 - val_mae: 0.0553 - learning_rate: 1.0000e-08
# Epoch 28/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - loss: 0.0350 - mae: 0.0350 - val_loss: 0.0553 - val_mae: 0.0553 - learning_rate: 1.0000e-08
# Epoch 29/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - loss: 0.0319 - mae: 0.0319 - val_loss: 0.0553 - val_mae: 0.0553 - learning_rate: 1.0000e-08
# Epoch 30/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - loss: 0.0357 - mae: 0.0357 - val_loss: 0.0553 - val_mae: 0.0553 - learning_rate: 1.0000e-09
# Epoch 31/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - loss: 0.0324 - mae: 0.0324 - val_loss: 0.0553 - val_mae: 0.0553 - learning_rate: 1.0000e-09
# Epoch 32/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - loss: 0.0340 - mae: 0.0340 - val_loss: 0.0553 - val_mae: 0.0553 - learning_rate: 1.0000e-09
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 17.

# %% [markdown]
# # Prediction

# %%
y_pred_train=model.predict(x_train,verbose=0).flatten()
y_pred_val=model.predict(x_val,verbose=0).flatten()
y_pred_test=model.predict(x_test,verbose=0).flatten()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
train_rmse = np.sqrt(mean_squared_error(y_train, y_pred_train))
train_mae = mean_absolute_error(y_train, y_pred_train)
train_r2 = r2_score(y_train, y_pred_train)

val_rmse = np.sqrt(mean_squared_error(y_val, y_pred_val))
val_mae = mean_absolute_error(y_val, y_pred_val)
val_r2 = r2_score(y_val, y_pred_val)

test_rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))
test_mae = mean_absolute_error(y_test, y_pred_test)
test_r2 = r2_score(y_test, y_pred_test)

print("\n" + "="*60)
print("MODEL EVALUATION RESULTS")
print("="*60)
print(f"\nTRAIN SET:")
print(f"  RMSE: {train_rmse:.6f}")
print(f"  MAE:  {train_mae:.6f}")
print(f"  R²:   {train_r2:.4f}")

print(f"\nVALIDATION SET:")
print(f"  RMSE: {val_rmse:.6f}")
print(f"  MAE:  {val_mae:.6f}")
print(f"  R²:   {val_r2:.4f}")

print(f"\nTEST SET:")
print(f"  RMSE: {test_rmse:.6f}")
print(f"  MAE:  {test_mae:.6f}")
print(f"  R²:   {test_r2:.4f}")
# Out:
# ============================================================
# MODEL EVALUATION RESULTS
# ============================================================
#
# TRAIN SET:
#   RMSE: 0.022147
#   MAE:  0.013799
#   R²:   0.9921
#
# VALIDATION SET:
#   RMSE: 0.065773
#   MAE:  0.053346
#   R²:   0.8345
#
# TEST SET:
#   RMSE: 0.073885
#   MAE:  0.064798
#   R²:   0.7024

# %%
def inverse_transform(y_value):
    dummy=np.zeros((len(y_value),len(features_cols)))
    dummy[:,target]=y_value
    dummy_inv=sclar.inverse_transform(dummy)
    return dummy_inv[:,target]

# %%
y_train_actual = inverse_transform(y_train)
y_pred_train_actual = inverse_transform(y_pred_train)
y_test_actual = inverse_transform(y_test)
y_pred_test_actual = inverse_transform(y_pred_test)
train_mae_actual = mean_absolute_error(y_train_actual, y_pred_train_actual)
test_mae_actual = mean_absolute_error(y_test_actual, y_pred_test_actual)
print(f' the mae for train data is {train_mae_actual}')
print(f' the mae for test data is {test_mae_actual}')
# Out:
#  the mae for train data is 8.79999102732992
#  the mae for test data is 41.32370276601814

# %%
plt.figure(figsize=(15,4))
train_plot_idx = df.index[lookback : lookback + len(y_train_actual)]
plt.plot(train_plot_idx, y_train_actual, color='r', label='Actual Train')
plt.plot(train_plot_idx, y_pred_train_actual, color='g', label='Predicted Train')
plt.savefig('Actual vs Predicted Train.png')
plt.show()

# %%
plt.figure(figsize=(15,4))
test_start_idx = val_end + lookback
test_plot_idx = df.index[test_start_idx : test_start_idx + len(y_test_actual)]
plt.plot(test_plot_idx, y_test_actual, color='r', label='Actual Test')
plt.plot(test_plot_idx, y_pred_test_actual, color='g', label='Predicted Test')
plt.savefig('Actual vs Predicted Test.png')
plt.grid()
plt.show()

# %%
import pickle
with open('Sclar.pkl','wb') as file:
    pickle.dump(sclar,file)

# %%
import os
import glob
import subprocess
import shutil
from datetime import datetime
from kaggle_secrets import UserSecretsClient

GITHUB_USERNAME = "Zalanemoj"
GITHUB_REPO = "General"
GITHUB_EMAIL = "zalanemoj777@gmail.com"
GITHUB_DIR = "Outputs_LSTM_HDFC_Prediction"
BRANCH = "main"

FILES_TO_PUSH = ["*.csv", "*.png", "*.jpg", "*.json","*.pkl"]
FOLDERS_TO_PUSH = ["*"]

TOKEN = UserSecretsClient().get_secret("GITHUB_TOKEN")
REPO_URL = f"https://{TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO}.git"

source = "/kaggle/working"
temp = "/kaggle/working/git_temp"

if os.path.exists(temp):
    shutil.rmtree(temp)
os.makedirs(temp)

os.chdir(temp)
subprocess.run(["git", "init"], capture_output=True)
subprocess.run(["git", "config", "user.email", GITHUB_EMAIL], capture_output=True)
subprocess.run(["git", "config", "user.name", GITHUB_USERNAME], capture_output=True)
subprocess.run(["git", "remote", "add", "origin", REPO_URL], capture_output=True)
subprocess.run(["git", "pull", "origin", BRANCH], capture_output=True)

target = os.path.join(temp, GITHUB_DIR)
os.makedirs(target, exist_ok=True)
IGNORE_FOLDERS = ["git_temp", ".virtual_documents", ".git"]
os.chdir(source)

print("Copying files:")
for pattern in FILES_TO_PUSH:
    for item in glob.glob(pattern):
        shutil.copy2(item, target)
        print(f"  ✓ {item}")

print("\nCopying folders:")
for pattern in FOLDERS_TO_PUSH:
    for folder in glob.glob(pattern):
        if any(ignored in folder for ignored in IGNORE_FOLDERS):
            continue

        if os.path.isdir(folder):
            dest = os.path.join(target, folder)
            if os.path.exists(dest):
                shutil.rmtree(dest)
            shutil.copytree(folder, dest)
            print(f"  ✓ {folder}/")

os.chdir(temp)
subprocess.run(["git", "add", "-A"], capture_output=True)
subprocess.run(["git", "commit", "-m", f"Update {datetime.now().strftime('%Y-%m-%d %H:%M')}"], capture_output=True)
subprocess.run(["git", "branch", "-M", BRANCH], capture_output=True)

result = subprocess.run(["git", "push", "-f", "origin", BRANCH], capture_output=True, text=True)

if result.returncode == 0:
    print(f"\n✅ Success! https://github.com/{GITHUB_USERNAME}/{GITHUB_REPO}/tree/{BRANCH}/{GITHUB_DIR}")
else:
    print(f"\n❌ Failed: {result.stderr}")

os.chdir(source)
# Out:
# Copying files:
#   ✓ Bar chart Volume.png
#   ✓ Closing Price vs Years.png
#   ✓ Actual vs Predicted Train.png
#   ✓ Actual vs Predicted Test.png
#   ✓ Closing Price vs Years with limit.png
#   ✓ Sclar.pkl
#
# Copying folders:
#   ✓ logs/
#
# ✅ Success! https://github.com/Zalanemoj/General/tree/main/Outputs_LSTM_HDFC_Prediction
